# %%
from citipy import citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       

        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | pevek
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | san quintin
# Processing Record 7 of Set 1 | muros
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | eyl
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | geraldton
# Processing Record 15 of Set 1 | coahuayana
# Processing Record 16 of Set 1 | muravlenko
# Processing Record 17 of Set 1 | manzhouli
# Processing Record 18 of Set 1 | bud
# Processing Record 19 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 1 | alappuzha
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | katsuura
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | almaznyy
# Processing Record 31 of Set 1 | nyurba
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | sulangan
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | sharjah
# Processing Record 41 of Set 1 | kiunga
# Processing Record 42 of Set 1 | chintamani
# Processing Record 43 of Set 1 | lata
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | marzuq
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | basco
# Processing Record 49 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 1 | krasnyy chikoy
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | aquiraz
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 2 | taoudenni
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | bafq
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | puerto escondido
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | coihaique
# Processing Record 16 of Set 2 | haines junction
# Processing Record 17 of Set 2 | cabinda
# Processing Record 18 of Set 2 | toora-khem
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | ugoofaaru
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 2 | vaitape
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | mehamn
# Processing Record 28 of Set 2 | grindavik
# Processing Record 29 of Set 2 | cabanas
# Processing Record 30 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | sugod
# Processing Record 34 of Set 2 | bisho
# Processing Record 35 of Set 2 | vardo
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | lovington
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | shelburne
# Processing Record 42 of Set 2 | kaeo
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | tevriz
# Processing Record 46 of Set 2 | north bend
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 2 | zyryanka
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | hervey bay
# Processing Record 3 of Set 3 | port macquarie
# Processing Record 4 of Set 3 | leningradskiy
# Processing Record 5 of Set 3 | marsh harbour
# Processing Record 6 of Set 3 | waingapu
# Processing Record 7 of Set 3 | anadyr
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | yarim
# Processing Record 11 of Set 3 | qingdao
# Processing Record 12 of Set 3 | verkhnyaya inta
# Processing Record 13 of Set 3 | hami
# Processing Record 14 of Set 3 | yambio
# Processing Record 15 of Set 3 | kargat
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | ust-nera
# Processing Record 20 of Set 3 | muromtsevo
# Processing Record 21 of Set 3 | luba
# Processing Record 22 of Set 3 | christchurch
# Processing Record 23 of Set 3 | lishui
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | rocha
# Processing Record 26 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | camacha
# Processing Record 29 of Set 3 | charyshskoye
# Processing Record 30 of Set 3 | newport
# Processing Record 31 of Set 3 | liuzhou
# Processing Record 32 of Set 3 | ramon
# Processing Record 33 of Set 3 | tautira
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | lavrentiya
# Processing Record 37 of Set 3 | kashi
# Processing Record 38 of Set 3 | samana
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | sao joao da barra
# Processing Record 41 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 3 | seoul
# Processing Record 43 of Set 3 | abu zabad
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | quatre cocos
# Processing Record 46 of Set 3 | paracuru
# Processing Record 47 of Set 3 | puerto baquerizo moreno
# Processing Record 48 of Set 3 | gornopravdinsk
# Processing Record 49 of Set 3 | omsukchan
# Processing Record 50 of Set 3 | grand forks
# Processing Record 1 of Set 4 | shaunavon
# Processing Record 2 of Set 4 | buchanan
# Processing Record 3 of Set 4 | harper
# Processing Record 4 of Set 4 | uyuni
# Processing Record 5 of Set 4 | phan thiet
# Processing Record 6 of Set 4 | piracanjuba
# Processing Record 7 of Set 4 | vila
# Processing Record 8 of Set 4 | borshchiv
# Processing Record 9 of Set 4 | laguna
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 4 | bonfim
# Processing Record 12 of Set 4 | bilibino
# Processing Record 13 of Set 4 | niquero
# Processing Record 14 of Set 4 | iseyin
# Processing Record 15 of Set 4 | nhulunbuy
# Processing Record 16 of Set 4 | yenagoa
# Processing Record 17 of Set 4 | reftinskiy
# Processing Record 18 of Set 4 | dukat
# Processing Record 19 of Set 4 | evanston
# Processing Record 20 of Set 4 | amga
# Processing Record 21 of Set 4 | luneville
# Processing Record 22 of Set 4 | tilichiki
# Processing Record 23 of Set 4 | turtkul
# City not found. Skipping...
# Processing Record 24 of Set 4 | matamoros
# Processing Record 25 of Set 4 | avarua
# Processing Record 26 of Set 4 | mar del plata
# Processing Record 27 of Set 4 | presidencia roque saenz pena
# Processing Record 28 of Set 4 | la ronge
# Processing Record 29 of Set 4 | izumo
# Processing Record 30 of Set 4 | warri
# Processing Record 31 of Set 4 | ilinskoye-khovanskoye
# Processing Record 32 of Set 4 | castlemaine
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | acarau
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | yerbogachen
# Processing Record 38 of Set 4 | kysyl-syr
# Processing Record 39 of Set 4 | lopatino
# Processing Record 40 of Set 4 | katangli
# Processing Record 41 of Set 4 | anklesvar
# City not found. Skipping...
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | high level
# Processing Record 44 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 4 | foumban
# Processing Record 46 of Set 4 | faya
# Processing Record 47 of Set 4 | oktyabrskiy
# Processing Record 48 of Set 4 | corrales
# Processing Record 49 of Set 4 | dibaya
# City not found. Skipping...
# Processing Record 50 of Set 4 | naze
# Processing Record 1 of Set 5 | daru
# Processing Record 2 of Set 5 | kendari
# Processing Record 3 of Set 5 | homer
# Processing Record 4 of Set 5 | umea
# Processing Record 5 of Set 5 | torbay
# Processing Record 6 of Set 5 | curaca
# Processing Record 7 of Set 5 | hegra
# Processing Record 8 of Set 5 | potsdam
# Processing Record 9 of Set 5 | san andres
# Processing Record 10 of Set 5 | hobbs
# Processing Record 11 of Set 5 | oyama
# Processing Record 12 of Set 5 | hobyo
# Processing Record 13 of Set 5 | half moon bay
# Processing Record 14 of Set 5 | tiarei
# Processing Record 15 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 5 | nishihara
# Processing Record 17 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 5 | thompson
# Processing Record 19 of Set 5 | bambous virieux
# Processing Record 20 of Set 5 | terre haute
# Processing Record 21 of Set 5 | santa
# Processing Record 22 of Set 5 | albanel
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | ierapetra
# Processing Record 25 of Set 5 | karlshamn
# Processing Record 26 of Set 5 | norman wells
# Processing Record 27 of Set 5 | ilulissat
# Processing Record 28 of Set 5 | fort nelson
# Processing Record 29 of Set 5 | dipkarpaz
# City not found. Skipping...
# Processing Record 30 of Set 5 | cabedelo
# Processing Record 31 of Set 5 | obluche
# City not found. Skipping...
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | kedrovyy
# Processing Record 34 of Set 5 | tasiilaq
# Processing Record 35 of Set 5 | mandiana
# Processing Record 36 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 5 | saint-augustin
# Processing Record 38 of Set 5 | la ferte-bernard
# Processing Record 39 of Set 5 | burdur
# Processing Record 40 of Set 5 | the valley
# Processing Record 41 of Set 5 | pombas
# Processing Record 42 of Set 5 | kishi
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | raymond
# Processing Record 45 of Set 5 | kalabo
# Processing Record 46 of Set 5 | la palma
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | okato
# Processing Record 49 of Set 5 | port augusta
# Processing Record 50 of Set 5 | bathsheba
# Processing Record 1 of Set 6 | olafsvik
# Processing Record 2 of Set 6 | nanortalik
# Processing Record 3 of Set 6 | chicama
# Processing Record 4 of Set 6 | sanok
# Processing Record 5 of Set 6 | adelanto
# Processing Record 6 of Set 6 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 7 of Set 6 | tuim
# Processing Record 8 of Set 6 | osypenko
# Processing Record 9 of Set 6 | westport
# Processing Record 10 of Set 6 | vestmannaeyjar
# Processing Record 11 of Set 6 | waipawa
# Processing Record 12 of Set 6 | hongjiang
# Processing Record 13 of Set 6 | prainha
# Processing Record 14 of Set 6 | provideniya
# Processing Record 15 of Set 6 | batagay-alyta
# Processing Record 16 of Set 6 | kavaratti
# Processing Record 17 of Set 6 | el dorado
# Processing Record 18 of Set 6 | qujing
# Processing Record 19 of Set 6 | anori
# Processing Record 20 of Set 6 | domoni
# Processing Record 21 of Set 6 | mujiayingzi
# Processing Record 22 of Set 6 | adrar
# Processing Record 23 of Set 6 | alofi
# Processing Record 24 of Set 6 | port lincoln
# Processing Record 25 of Set 6 | hammerfest
# Processing Record 26 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 6 | singapore
# Processing Record 28 of Set 6 | makakilo city
# Processing Record 29 of Set 6 | dalmatovo
# Processing Record 30 of Set 6 | maceio
# Processing Record 31 of Set 6 | bandarbeyla
# Processing Record 32 of Set 6 | paranaiba
# Processing Record 33 of Set 6 | college
# Processing Record 34 of Set 6 | sterling
# Processing Record 35 of Set 6 | dibulla
# Processing Record 36 of Set 6 | grand gaube
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | teya
# Processing Record 39 of Set 6 | adolfo lopez mateos
# Processing Record 40 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 6 | nadym
# Processing Record 42 of Set 6 | pisco
# Processing Record 43 of Set 6 | myanaung
# Processing Record 44 of Set 6 | isla vista
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | duz
# City not found. Skipping...
# Processing Record 47 of Set 6 | oktyabrskoye
# Processing Record 48 of Set 6 | raga
# Processing Record 49 of Set 6 | uglegorsk
# Processing Record 50 of Set 6 | urusha
# Processing Record 1 of Set 7 | gorontalo
# Processing Record 2 of Set 7 | alyangula
# Processing Record 3 of Set 7 | cherskiy
# Processing Record 4 of Set 7 | sept-iles
# Processing Record 5 of Set 7 | el tigre
# Processing Record 6 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 7 of Set 7 | bubaque
# Processing Record 8 of Set 7 | elliot lake
# Processing Record 9 of Set 7 | broken hill
# Processing Record 10 of Set 7 | matay
# Processing Record 11 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 7 | ouesso
# Processing Record 13 of Set 7 | puerto rico
# Processing Record 14 of Set 7 | saint-ambroise
# Processing Record 15 of Set 7 | bolshaya murta
# City not found. Skipping...
# Processing Record 16 of Set 7 | ningyang
# Processing Record 17 of Set 7 | anzio
# Processing Record 18 of Set 7 | skjervoy
# Processing Record 19 of Set 7 | sawtell
# Processing Record 20 of Set 7 | balikpapan
# Processing Record 21 of Set 7 | baherden
# Processing Record 22 of Set 7 | nouakchott
# Processing Record 23 of Set 7 | vestmanna
# Processing Record 24 of Set 7 | comodoro rivadavia
# Processing Record 25 of Set 7 | yulara
# Processing Record 26 of Set 7 | camana
# Processing Record 27 of Set 7 | salinas
# Processing Record 28 of Set 7 | monastyrshchina
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | clyde river
# Processing Record 31 of Set 7 | gaillac
# Processing Record 32 of Set 7 | amazar
# Processing Record 33 of Set 7 | mahebourg
# Processing Record 34 of Set 7 | inhambane
# Processing Record 35 of Set 7 | fairbanks
# Processing Record 36 of Set 7 | diamantino
# Processing Record 37 of Set 7 | raudeberg
# Processing Record 38 of Set 7 | missoula
# Processing Record 39 of Set 7 | saint-georges
# Processing Record 40 of Set 7 | portland
# Processing Record 41 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 42 of Set 7 | san policarpo
# Processing Record 43 of Set 7 | maldonado
# Processing Record 44 of Set 7 | shingu
# Processing Record 45 of Set 7 | pauini
# Processing Record 46 of Set 7 | kavieng
# Processing Record 47 of Set 7 | rawson
# Processing Record 48 of Set 7 | kempsey
# Processing Record 49 of Set 7 | eureka
# Processing Record 50 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 8 | baillif
# Processing Record 2 of Set 8 | teruel
# Processing Record 3 of Set 8 | bogorodskoye
# Processing Record 4 of Set 8 | bajos de haina
# Processing Record 5 of Set 8 | burnie
# Processing Record 6 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 8 | port-gentil
# Processing Record 8 of Set 8 | calarasi
# Processing Record 9 of Set 8 | medvedevo
# Processing Record 10 of Set 8 | yumen
# Processing Record 11 of Set 8 | teguldet
# Processing Record 12 of Set 8 | guerrero negro
# Processing Record 13 of Set 8 | kahului
# Processing Record 14 of Set 8 | narsaq
# Processing Record 15 of Set 8 | casablanca
# Processing Record 16 of Set 8 | ardalstangen
# Processing Record 17 of Set 8 | marienburg
# Processing Record 18 of Set 8 | dunedin
# Processing Record 19 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 8 | west wendover
# Processing Record 21 of Set 8 | rabaul
# Processing Record 22 of Set 8 | hirado
# Processing Record 23 of Set 8 | victoria
# Processing Record 24 of Set 8 | iberia
# Processing Record 25 of Set 8 | canon city
# Processing Record 26 of Set 8 | washington
# Processing Record 27 of Set 8 | gualeguay
# Processing Record 28 of Set 8 | kindu
# Processing Record 29 of Set 8 | igarka
# Processing Record 30 of Set 8 | viedma
# Processing Record 31 of Set 8 | kayes
# Processing Record 32 of Set 8 | lebu
# Processing Record 33 of Set 8 | sakakah
# Processing Record 34 of Set 8 | cayenne
# Processing Record 35 of Set 8 | gat
# Processing Record 36 of Set 8 | coquimbo
# Processing Record 37 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 38 of Set 8 | moen
# Processing Record 39 of Set 8 | tuatapere
# Processing Record 40 of Set 8 | longyan
# Processing Record 41 of Set 8 | sinnamary
# Processing Record 42 of Set 8 | sangar
# Processing Record 43 of Set 8 | kununurra
# Processing Record 44 of Set 8 | jaque
# Processing Record 45 of Set 8 | labuan
# Processing Record 46 of Set 8 | pankrushikha
# Processing Record 47 of Set 8 | dese
# Processing Record 48 of Set 8 | hamilton
# Processing Record 49 of Set 8 | cabo san lucas
# Processing Record 50 of Set 8 | volterra
# Processing Record 1 of Set 9 | mana
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | aksu
# Processing Record 4 of Set 9 | mount gambier
# Processing Record 5 of Set 9 | kinablangan
# Processing Record 6 of Set 9 | winneba
# Processing Record 7 of Set 9 | avera
# Processing Record 8 of Set 9 | maniitsoq
# Processing Record 9 of Set 9 | kutum
# Processing Record 10 of Set 9 | huadian
# Processing Record 11 of Set 9 | swan hill
# Processing Record 12 of Set 9 | parangan
# Processing Record 13 of Set 9 | moose factory
# Processing Record 14 of Set 9 | okhotsk
# Processing Record 15 of Set 9 | almeirim
# Processing Record 16 of Set 9 | yerofey pavlovich
# Processing Record 17 of Set 9 | richards bay
# Processing Record 18 of Set 9 | hokitika
# Processing Record 19 of Set 9 | villamontes
# Processing Record 20 of Set 9 | imbituba
# Processing Record 21 of Set 9 | kampong thum
# Processing Record 22 of Set 9 | alekseyevka
# Processing Record 23 of Set 9 | vallenar
# Processing Record 24 of Set 9 | olga
# Processing Record 25 of Set 9 | mbekenyera
# Processing Record 26 of Set 9 | dingle
# Processing Record 27 of Set 9 | mariental
# Processing Record 28 of Set 9 | lubuk pakam
# Processing Record 29 of Set 9 | itarema
# Processing Record 30 of Set 9 | mauriti
# Processing Record 31 of Set 9 | dzaoudzi
# Processing Record 32 of Set 9 | beloha
# Processing Record 33 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 34 of Set 9 | ordu
# Processing Record 35 of Set 9 | mufulira
# Processing Record 36 of Set 9 | marrakesh
# Processing Record 37 of Set 9 | belle fourche
# Processing Record 38 of Set 9 | bonavista
# Processing Record 39 of Set 9 | ukiah
# Processing Record 40 of Set 9 | ust-maya
# Processing Record 41 of Set 9 | spring hill
# Processing Record 42 of Set 9 | aberystwyth
# Processing Record 43 of Set 9 | marawi
# Processing Record 44 of Set 9 | gambela
# Processing Record 45 of Set 9 | zhuzhou
# Processing Record 46 of Set 9 | borogontsy
# Processing Record 47 of Set 9 | le creusot
# Processing Record 48 of Set 9 | henties bay
# Processing Record 49 of Set 9 | callaway
# Processing Record 50 of Set 9 | ouricuri
# Processing Record 1 of Set 10 | mbanza-ngungu
# Processing Record 2 of Set 10 | ostrovnoy
# Processing Record 3 of Set 10 | alice springs
# Processing Record 4 of Set 10 | husavik
# Processing Record 5 of Set 10 | xining
# Processing Record 6 of Set 10 | meulaboh
# Processing Record 7 of Set 10 | tonj
# Processing Record 8 of Set 10 | vanimo
# Processing Record 9 of Set 10 | nakhon pathom
# Processing Record 10 of Set 10 | pithora
# Processing Record 11 of Set 10 | wanning
# Processing Record 12 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 10 | sturgeon bay
# Processing Record 14 of Set 10 | sisimiut
# Processing Record 15 of Set 10 | paoua
# Processing Record 16 of Set 10 | tehachapi
# Processing Record 17 of Set 10 | sainte-martine
# Processing Record 18 of Set 10 | novoilinsk
# Processing Record 19 of Set 10 | rotnes
# Processing Record 20 of Set 10 | liverpool
# Processing Record 21 of Set 10 | kruisfontein
# Processing Record 22 of Set 10 | swietochlowice
# Processing Record 23 of Set 10 | macau
# Processing Record 24 of Set 10 | umm lajj
# Processing Record 25 of Set 10 | mbandaka
# Processing Record 26 of Set 10 | vila velha
# Processing Record 27 of Set 10 | shar
# Processing Record 28 of Set 10 | usinsk
# Processing Record 29 of Set 10 | huarmey
# Processing Record 30 of Set 10 | sao jose da coroa grande
# Processing Record 31 of Set 10 | gazli
# Processing Record 32 of Set 10 | limbang
# Processing Record 33 of Set 10 | ahipara
# Processing Record 34 of Set 10 | tucuman
# Processing Record 35 of Set 10 | grajewo
# Processing Record 36 of Set 10 | muhos
# Processing Record 37 of Set 10 | whitehorse
# Processing Record 38 of Set 10 | touros
# Processing Record 39 of Set 10 | barra dos coqueiros
# Processing Record 40 of Set 10 | northam
# Processing Record 41 of Set 10 | santiago de cao
# Processing Record 42 of Set 10 | soyo
# Processing Record 43 of Set 10 | sao miguel do araguaia
# Processing Record 44 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 10 | salalah
# Processing Record 46 of Set 10 | sabzevar
# Processing Record 47 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 10 | palizada
# Processing Record 49 of Set 10 | raghunathpur
# Processing Record 50 of Set 10 | duobao
# Processing Record 1 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 11 | shirakawa
# Processing Record 3 of Set 11 | axim
# Processing Record 4 of Set 11 | dawei
# Processing Record 5 of Set 11 | port hedland
# Processing Record 6 of Set 11 | matara
# Processing Record 7 of Set 11 | bima
# Processing Record 8 of Set 11 | berea
# Processing Record 9 of Set 11 | boddam
# Processing Record 10 of Set 11 | kon tum
# Processing Record 11 of Set 11 | akdepe
# Processing Record 12 of Set 11 | baykit
# Processing Record 13 of Set 11 | port blair
# Processing Record 14 of Set 11 | kailua
# Processing Record 15 of Set 11 | gamba
# Processing Record 16 of Set 11 | dallas
# Processing Record 17 of Set 11 | innisfail
# Processing Record 18 of Set 11 | agadez
# Processing Record 19 of Set 11 | waddan
# Processing Record 20 of Set 11 | wau
# Processing Record 21 of Set 11 | messina
# Processing Record 22 of Set 11 | teguise
# Processing Record 23 of Set 11 | necochea
# Processing Record 24 of Set 11 | muli
# Processing Record 25 of Set 11 | melfi
# Processing Record 26 of Set 11 | porto san giorgio
# Processing Record 27 of Set 11 | mon
# Processing Record 28 of Set 11 | deputatskiy
# Processing Record 29 of Set 11 | shitanjing
# Processing Record 30 of Set 11 | korla
# Processing Record 31 of Set 11 | lasa
# Processing Record 32 of Set 11 | blairmore
# Processing Record 33 of Set 11 | nyaunglebin
# Processing Record 34 of Set 11 | tigzirt
# Processing Record 35 of Set 11 | piney green
# Processing Record 36 of Set 11 | port hawkesbury
# Processing Record 37 of Set 11 | huangnihe
# Processing Record 38 of Set 11 | kenai
# Processing Record 39 of Set 11 | tazovskiy
# Processing Record 40 of Set 11 | kizema
# Processing Record 41 of Set 11 | dolores
# Processing Record 42 of Set 11 | arzgir
# Processing Record 43 of Set 11 | aliaga
# Processing Record 44 of Set 11 | am timan
# Processing Record 45 of Set 11 | kimbe
# Processing Record 46 of Set 11 | balgazyn
# Processing Record 47 of Set 11 | mongo
# Processing Record 48 of Set 11 | leh
# Processing Record 49 of Set 11 | takab
# Processing Record 50 of Set 11 | isangel
# Processing Record 1 of Set 12 | oranjemund
# Processing Record 2 of Set 12 | iroquois falls
# Processing Record 3 of Set 12 | marystown
# Processing Record 4 of Set 12 | mahendranagar
# Processing Record 5 of Set 12 | andenes
# Processing Record 6 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 7 of Set 12 | tangshan
# Processing Record 8 of Set 12 | san rafael
# Processing Record 9 of Set 12 | taonan
# Processing Record 10 of Set 12 | srednekolymsk
# Processing Record 11 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 12 | san cristobal
# Processing Record 13 of Set 12 | sorland
# Processing Record 14 of Set 12 | palmer
# Processing Record 15 of Set 12 | ixtapa
# Processing Record 16 of Set 12 | coihueco
# Processing Record 17 of Set 12 | araouane
# Processing Record 18 of Set 12 | jabinyanah
# Processing Record 19 of Set 12 | caravelas
# Processing Record 20 of Set 12 | yeniseysk
# Processing Record 21 of Set 12 | trincomalee
# Processing Record 22 of Set 12 | zhiryatino
# Processing Record 23 of Set 12 | obo
# Processing Record 24 of Set 12 | cartagena
# Processing Record 25 of Set 12 | cocula
# Processing Record 26 of Set 12 | turukhansk
# Processing Record 27 of Set 12 | ballina
# Processing Record 28 of Set 12 | ploufragan
# Processing Record 29 of Set 12 | el vigia
# Processing Record 30 of Set 12 | abha
# Processing Record 31 of Set 12 | imeni stepana razina
# Processing Record 32 of Set 12 | warrington
# Processing Record 33 of Set 12 | chibombo
# Processing Record 34 of Set 12 | farah
# Processing Record 35 of Set 12 | kurdzhinovo
# Processing Record 36 of Set 12 | inirida
# Processing Record 37 of Set 12 | los llanos de aridane
# Processing Record 38 of Set 12 | viseu
# Processing Record 39 of Set 12 | aden
# Processing Record 40 of Set 12 | rodrigues alves
# Processing Record 41 of Set 12 | beringovskiy
# Processing Record 42 of Set 12 | natal
# Processing Record 43 of Set 12 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 44 of Set 12 | shimoda
# Processing Record 45 of Set 12 | russell
# Processing Record 46 of Set 12 | dicabisagan
# Processing Record 47 of Set 12 | auki
# Processing Record 48 of Set 12 | kesova gora
# Processing Record 49 of Set 12 | conde
# Processing Record 50 of Set 12 | turan
# Processing Record 1 of Set 13 | sibolga
# Processing Record 2 of Set 13 | clarksdale
# Processing Record 3 of Set 13 | abu samrah
# Processing Record 4 of Set 13 | poum
# Processing Record 5 of Set 13 | sechura
# Processing Record 6 of Set 13 | shcholkine
# City not found. Skipping...
# Processing Record 7 of Set 13 | san ramon
# Processing Record 8 of Set 13 | cockburn town
# Processing Record 9 of Set 13 | saint-pierre
# Processing Record 10 of Set 13 | tucuma
# Processing Record 11 of Set 13 | pindushi
# Processing Record 12 of Set 13 | krasnoselkup
# Processing Record 13 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 13 | tual
# Processing Record 15 of Set 13 | bozova
# Processing Record 16 of Set 13 | skibbereen
# Processing Record 17 of Set 13 | lima
# Processing Record 18 of Set 13 | san-pedro
# Processing Record 19 of Set 13 | mustasaari
# Processing Record 20 of Set 13 | lagoa
# Processing Record 21 of Set 13 | saint-francois
# Processing Record 22 of Set 13 | accra
# Processing Record 23 of Set 13 | juneau
# Processing Record 24 of Set 13 | samarai
# Processing Record 25 of Set 13 | nantucket
# Processing Record 26 of Set 13 | melekhovskaya
# City not found. Skipping...
# Processing Record 27 of Set 13 | nikki
# Processing Record 28 of Set 13 | manokwari
# Processing Record 29 of Set 13 | zvishavane
# Processing Record 30 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 31 of Set 13 | klaksvik
# Processing Record 32 of Set 13 | aykhal
# Processing Record 33 of Set 13 | san jeronimo
# Processing Record 34 of Set 13 | mangaratiba
# Processing Record 35 of Set 13 | new ulm
# Processing Record 36 of Set 13 | pangnirtung
# Processing Record 37 of Set 13 | tashigang
# Processing Record 38 of Set 13 | winnemucca
# Processing Record 39 of Set 13 | sirjan
# Processing Record 40 of Set 13 | labuhan
# Processing Record 41 of Set 13 | bingerville
# Processing Record 42 of Set 13 | sambalpur
# Processing Record 43 of Set 13 | ayorou
# Processing Record 44 of Set 13 | nemuro
# Processing Record 45 of Set 13 | ovalle
# Processing Record 46 of Set 13 | sambava
# Processing Record 47 of Set 13 | bjerkvik
# Processing Record 48 of Set 13 | flin flon
# Processing Record 49 of Set 13 | vanavara
# Processing Record 50 of Set 13 | kloulklubed
# Processing Record 1 of Set 14 | tananger
# Processing Record 2 of Set 14 | port hardy
# Processing Record 3 of Set 14 | anchorage
# Processing Record 4 of Set 14 | naples
# Processing Record 5 of Set 14 | puerto suarez
# Processing Record 6 of Set 14 | ancud
# Processing Record 7 of Set 14 | erenhot
# Processing Record 8 of Set 14 | benguela
# Processing Record 9 of Set 14 | taltal
# Processing Record 10 of Set 14 | linguere
# Processing Record 11 of Set 14 | kayasula
# Processing Record 12 of Set 14 | tura
# Processing Record 13 of Set 14 | buraydah
# Processing Record 14 of Set 14 | alexandria
# Processing Record 15 of Set 14 | moroni
# Processing Record 16 of Set 14 | sistranda
# Processing Record 17 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 14 | hofn
# Processing Record 19 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 14 | painesville
# Processing Record 21 of Set 14 | mogadishu
# Processing Record 22 of Set 14 | pocone
# Processing Record 23 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 14 | rozavlea
# Processing Record 25 of Set 14 | alta floresta
# Processing Record 26 of Set 14 | shenjiamen
# Processing Record 27 of Set 14 | jinji
# Processing Record 28 of Set 14 | pilar
# Processing Record 29 of Set 14 | harsewinkel
# Processing Record 30 of Set 14 | zhigansk
# Processing Record 31 of Set 14 | awbari
# Processing Record 32 of Set 14 | bonthe
# Processing Record 33 of Set 14 | sergeyevka
# Processing Record 34 of Set 14 | tecoanapa
# Processing Record 35 of Set 14 | kuusamo
# Processing Record 36 of Set 14 | mandurah
# Processing Record 37 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 38 of Set 14 | asfi
# Processing Record 39 of Set 14 | san jose
# Processing Record 40 of Set 14 | boca do acre
# Processing Record 41 of Set 14 | klyuchi
# Processing Record 42 of Set 14 | soto la marina
# Processing Record 43 of Set 14 | tequila
# Processing Record 44 of Set 14 | ambilobe
# Processing Record 45 of Set 14 | krasnoarmeysk
# Processing Record 46 of Set 14 | akcakoca
# Processing Record 47 of Set 14 | aksarka
# Processing Record 48 of Set 14 | chapais
# Processing Record 49 of Set 14 | cordun
# Processing Record 50 of Set 14 | stephenville
# Processing Record 1 of Set 15 | vao
# Processing Record 2 of Set 15 | kupang
# Processing Record 3 of Set 15 | banepa
# Processing Record 4 of Set 15 | chimbote
# Processing Record 5 of Set 15 | karlskrona
# Processing Record 6 of Set 15 | kerrobert
# Processing Record 7 of Set 15 | vangaindrano
# Processing Record 8 of Set 15 | kitui
# Processing Record 9 of Set 15 | cap malheureux
# Processing Record 10 of Set 15 | natchez
# Processing Record 11 of Set 15 | la baule-escoublac
# Processing Record 12 of Set 15 | sao felipe
# Processing Record 13 of Set 15 | batemans bay
# Processing Record 14 of Set 15 | mundo novo
# Processing Record 15 of Set 15 | skerries
# Processing Record 16 of Set 15 | paamiut
# Processing Record 17 of Set 15 | kerman
# Processing Record 18 of Set 15 | cairo
# Processing Record 19 of Set 15 | sidirokastron
# City not found. Skipping...
# Processing Record 20 of Set 15 | mehrabpur
# Processing Record 21 of Set 15 | cachoeira do sul
# Processing Record 22 of Set 15 | promyshlennovskiy
# Processing Record 23 of Set 15 | piranhas
# Processing Record 24 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 15 | mount isa
# Processing Record 26 of Set 15 | colares
# Processing Record 27 of Set 15 | broome
# Processing Record 28 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 29 of Set 15 | jodar
# Processing Record 30 of Set 15 | nueva gerona
# Processing Record 31 of Set 15 | badou
# Processing Record 32 of Set 15 | corinto
# Processing Record 33 of Set 15 | chumikan
# Processing Record 34 of Set 15 | gubkinskiy
# Processing Record 35 of Set 15 | tam ky
# Processing Record 36 of Set 15 | kirakira
# Processing Record 37 of Set 15 | losal
# Processing Record 38 of Set 15 | ondjiva
# Processing Record 39 of Set 15 | thinadhoo
# Processing Record 40 of Set 15 | ghogha
# Processing Record 41 of Set 15 | sola
# Processing Record 42 of Set 15 | birjand
# Processing Record 43 of Set 15 | sao filipe
# Processing Record 44 of Set 15 | ballangen
# Processing Record 45 of Set 15 | farsund
# Processing Record 46 of Set 15 | merauke
# Processing Record 47 of Set 15 | peleduy
# Processing Record 48 of Set 15 | shu
# Processing Record 49 of Set 15 | preobrazheniye
# Processing Record 50 of Set 15 | karratha
# Processing Record 1 of Set 16 | roald
# Processing Record 2 of Set 16 | florianopolis
# Processing Record 3 of Set 16 | la rioja
# Processing Record 4 of Set 16 | kameshkovo
# Processing Record 5 of Set 16 | chingirlau
# Processing Record 6 of Set 16 | bredy
# Processing Record 7 of Set 16 | kabanjahe
# Processing Record 8 of Set 16 | pinawa
# Processing Record 9 of Set 16 | lumeje
# Processing Record 10 of Set 16 | puerto ayacucho
# Processing Record 11 of Set 16 | hambantota
# Processing Record 12 of Set 16 | luganville
# Processing Record 13 of Set 16 | dwarka
# Processing Record 14 of Set 16 | dan khun thot
# Processing Record 15 of Set 16 | khani
# Processing Record 16 of Set 16 | ituni
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0    Puerto Ayora  -0.7393  -90.3518     72.55          few clouds        96
# 1         Mataura -46.1927  168.8643     57.47          few clouds        59
# 2           Pevek  69.7008  170.3133     30.13    scattered clouds        77
# 3      Bredasdorp -34.5322   20.0403     60.15     overcast clouds        70
# 4  Severo-Kurilsk  50.6789  156.1250     36.21          light rain        98
# 5     San Quintin  30.4833 -115.9500     61.20     overcast clouds        66
# 6           Muros  42.7762   -9.0603     51.10          few clouds        89
# 7         Rikitea -23.1203 -134.9692     76.87           clear sky        70
# 8    San Patricio  28.0170  -97.5169     80.85    scattered clouds        80
# 9         Iqaluit  63.7506  -68.5145     29.93          light snow       100
#
#    Cloudiness  Wind Speed Country
# 0          19        4.00      EC
# 1          15        3.53      NZ
# 2          28        9.51      RU
# 3          99       13.29      ZA
# 4         100        9.86      RU
# 5          94       23.47      MX
# 6          20        3.31      ES
# 7          10       14.94      PF
# 8          50       15.84      US
# 9         100       16.11      CA

# %%
# Reorder columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed, so they are easy to read
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Puerto Ayora      EC  -0.7393  -90.3518     72.55        96          19
# 1         Mataura      NZ -46.1927  168.8643     57.47        59          15
# 2           Pevek      RU  69.7008  170.3133     30.13        77          28
# 3      Bredasdorp      ZA -34.5322   20.0403     60.15        70          99
# 4  Severo-Kurilsk      RU  50.6789  156.1250     36.21        98         100
# 5     San Quintin      MX  30.4833 -115.9500     61.20        66          94
# 6           Muros      ES  42.7762   -9.0603     51.10        89          20
# 7         Rikitea      PF -23.1203 -134.9692     76.87        70          10
# 8    San Patricio      US  28.0170  -97.5169     80.85        80          50
# 9         Iqaluit      CA  63.7506  -68.5145     29.93       100         100
#
#    Wind Speed Current Description
# 0        4.00          few clouds
# 1        3.53          few clouds
# 2        9.51    scattered clouds
# 3       13.29     overcast clouds
# 4        9.86          light rain
# 5       23.47     overcast clouds
# 6        3.31          few clouds
# 7       14.94           clear sky
# 8       15.84    scattered clouds
# 9       16.11          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
